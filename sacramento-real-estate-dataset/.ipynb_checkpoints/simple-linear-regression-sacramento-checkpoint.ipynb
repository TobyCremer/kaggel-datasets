# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Simple Linear Regression with Sacramento Real Estate Data
#
# _Authors: Matt Brems, Sam Stack_
#
# ---
#
# In this lab you will hone your EDA skills and practice constructing simple linear regressions using a dataset on Sacramento real estate sales.  The dataset contains information on qualities of the property, location of the property, and time of sale.

# %% [markdown]
# ### 1. Read in the Sacramento housing data set.

# %%
sac_csv = './datasets/sacramento_real_estate_transactions.csv'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats

# %matplotlib inline

# %% [markdown]
# ### 2. Conduct exploratory data analysis on this data set.
#
# **Report any notable findings here and any steps you take to clean/process data.**
#
# > **Note:** These EDA checks should be done on every data set we give you. If you find yourself checking for, say, missing/corrupted data over and over, it might be to your long-term benefit to have a function that you can re-use every time you're given some new data.

# %%
# Lets read in the Scaramento CSV and load as a Pandas DataFrame

shd = pd.read_csv(sac_csv)
shd.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
# Lets check the datatypes using dtypes

shd.dtypes
# Note that the zipcode is an integer however I think it should be a string
# Out:
# street        object
# city          object
# zip            int64
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
# Here I will change the zip code from a int64 to a string

shd.zip = shd.zip.astype(str)
shd.dtypes
# Note below the change has been made
# Out:
# street        object
# city          object
# zip           object
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
shd.describe().T

# Lets look at each of the columns
# It looks like some of the houses have zero beds
# It looks like some of the houses have zero baths
# Note the lowest square footage is a negative
# There is also a house with a negative price
# Out:
#            count           mean            std            min            25%  \
# beds       985.0       2.911675       1.307932       0.000000       2.000000
# baths      985.0       1.776650       0.895371       0.000000       1.000000
# sq__ft     985.0    1312.918782     856.123224    -984.000000     950.000000
# price      985.0  233715.951269  139088.818896 -210944.000000  145000.000000
# latitude   985.0      38.445121       5.103637    -121.503471      38.482704
# longitude  985.0    -121.193371       5.100670    -121.551704    -121.446119
#
#                      50%            75%            max
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# latitude       38.625932      38.695589      39.020808
# longitude    -121.375799    -121.294893      38.668433

# %%
# Lets explore the houses types column
    
shd.type.value_counts()
# Note there is one house that is labeled 'unknown', lets investigate further
# Out:
# Residential     917
# Condo            54
# Multi-Family     13
# Unkown            1
# Name: type, dtype: int64

# %%
shd[shd.type == 'Unkown']
# Out:
#                 street             city    zip state  beds  baths  sq__ft  \
# 757  6007 MARYBELLE LN  SHINGLE SPRINGS  95682    CA     0      0       0
#
#        type                     sale_date   price  latitude   longitude
# 757  Unkown  Fri May 16 00:00:00 EDT 2008  275000  38.64347 -120.888183

# %%
# Lets drop this column

shd.drop(757, inplace=True)
shd.shape
# Note, one less row
# Out:
# (984, 12)

# %%
# Lets lok at the beds column to see the houses with zero beds

shd.beds.value_counts()
# Note below there are 107 houses with zero beds
# Out:
# 3    413
# 4    258
# 2    133
# 0    107
# 5     59
# 1     10
# 6      3
# 8      1
# Name: beds, dtype: int64

# %%
# Lets take a closer look at these houses

shd[shd.beds == 0]
# It seems there are 107 houses with zero, beds and baths
# Out:
#                        street             city    zip state  beds  baths  \
# 73              17 SERASPI CT       SACRAMENTO  95834    CA     0      0
# 89           2866 KARITSA AVE       SACRAMENTO  95833    CA     0      0
# 100     12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# 121       5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0      0
# 126       2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0      0
# ..                        ...              ...    ...   ...   ...    ...
# 901  1530 TOPANGA LN Unit 204          LINCOLN  95648    CA     0      0
# 917            501 POPLAR AVE  WEST SACRAMENTO  95691    CA     0      0
# 934  1550 TOPANGA LN Unit 207          LINCOLN  95648    CA     0      0
# 947     1525 PENNSYLVANIA AVE  WEST SACRAMENTO  95691    CA     0      0
# 970             3557 SODA WAY       SACRAMENTO  95834    CA     0      0
#
#      sq__ft         type                     sale_date   price   latitude  \
# ...

# %%
# Lets remove these rows

shd = shd[shd.beds != 0]
# Note we romve using the opposite logic by identifying all the houses where beds are not zero

# %%
# Lets deal the with house with a negative price

shd[shd.price < 0]
# This is alos the house with a negative square feet
# Out:
#                street        city    zip state  beds  baths  sq__ft   type  \
# 703  1900 DANBROOK DR  SACRAMENTO  95835    AC     1      1    -984  Condo
#
#                         sale_date   price    latitude  longitude
# 703  Fri May 16 00:00:00 EDT 2008 -210944 -121.503471  38.668433

# %%
# Lets drop this row

shd.drop(703, inplace=True)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Lets look at the houses with zero square feet

shd[shd.sq__ft == 0]
# Out:
#                                  street             city    zip state  beds  \
# 132                 3020 RICHARDSON CIR  EL DORADO HILLS  95762    CA     3
# 154                    6030 PALERMO WAY  EL DORADO HILLS  95762    CA     4
# 155                     4070 REDONDO DR  EL DORADO HILLS  95762    CA     4
# 157                        315 JUMEL CT  EL DORADO HILLS  95762    CA     6
# 223                      2778 KAWEAH CT     CAMERON PARK  95682    CA     3
# ..                                  ...              ...    ...   ...   ...
# 863                    2982 ABERDEEN LN  EL DORADO HILLS  95762    CA     4
# 865                3720 VISTA DE MADERA          LINCOLN  95648    CA     3
# 922  10001 WOODCREEK OAKS BLVD Unit 815        ROSEVILLE  95747    CA     2
# 966                    9197 CORTINA CIR        ROSEVILLE  95678    CA     3
# 973                2181 WINTERHAVEN CIR     CAMERON PARK  95682    CA     3
#
# ...

# %%
# Lets drop these as well, we could have also tried to impute the estimated square feet, but we didnt

shd = shd[shd.sq__ft != 0]

# %%
shd.describe().T

# Now it looks like we have cleaned the dataset ready for analysis or modelling
# Out:
#            count           mean            std          min            25%  \
# beds       813.0       3.247232       0.849012     1.000000       3.000000
# baths      813.0       1.961870       0.669367     1.000000       2.000000
# sq__ft     813.0    1591.892989     663.908347   484.000000    1144.000000
# price      813.0  229471.130381  119897.576889  2000.000000  148750.000000
# latitude   813.0      38.576931       0.126352    38.241514      38.473814
# longitude  813.0    -121.378533       0.119730  -121.550527    -121.451444
#
#                      50%            75%            max
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1419.000000    1851.000000    5822.000000
# price      207973.000000  285000.000000  884790.000000
# latitude       38.591618      38.674864      39.008159
# longitude    -121.404999    -121.325730    -120.597599

# %%
sns.scatterplot(x=shd.longitude, y=shd.latitude, size=shd['sq__ft'], sizes=(20,200), hue=shd['beds'])

# %%
sns.pairplot(shd, hue='zip')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### 3. Our goal will be to predict price. List variables that you think qualify as predictors of price in a SLR model.
#
# **For each of these variables you believe to be valid potential predictors in an SLR model, generate a plot showing the relationship between the independent variable and dependent variable.**

# %%
shd.dtypes

# Note now for modelling there are only three numericl variables
# Out:
# street        object
# city          object
# zip           object
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
sns.lmplot(x='sq__ft', y='price', data=shd)
plt.show()
sns.lmplot(x='beds', y='price', data=shd)
plt.show()
sns.lmplot(x='baths', y='price', data=shd)
plt.show()

# %% [markdown]
# ### 4. Which variable would be the best predictor of Y in a SLR model? Why?

# %%
# A: From above it looks like there is a good linear relationship between square feet and price.
# Lets use this for modelling

# %% [markdown]
# ### 5. Build a function that will take in two lists `Y` and `X` and returns the intercept and slope coefficients that minimize SSE.
#
# `Y` is the target variable and `X` is the predictor variable.
#
# - **Test your function on price and the variable you determined was the best predictor in Problem 4.**
# - **Report the slope and intercept.**

# %%
# Get the optimal Slope and y intercept

def lin_reg(x,y):
    # Using other libraries for standard Deviation and Pearson Correlation Coef.
    # Note that in SLR, the correlation coefficient multiplied by the standard
    # deviation of y divided by standard deviation of x is the optimal slope.
    beta_1 = (scipy.stats.pearsonr(x,y)[0])*(np.std(y)/np.std(x))
    
    # Pearson Co. Coef returns a tuple so it needs to be sliced/indexed
    # the optimal beta is found by: mean(y) - b1 * mean(x)
    beta_0 = np.mean(y)-(beta_1*np.mean(x)) 
    
    #Print the Optimal Values
    print('The Optimal Y Intercept is ', beta_0)
    print('The Optimal slope is ', beta_1)

# %%
x = shd['sq__ft'].values
y = shd['price'].values
lin_reg(x,y)
# Out:
# The Optimal Y Intercept is  29984.361726519768
# The Optimal slope is  125.31418257510141

# %% [markdown]
# ### 6. Interpret the intercept. Interpret the slope.

# %%
# The intercept is the relative value that our y value starts at which is $29,984

# The slope is 125 which means every increase in 1 square feet the price increases by $125

# %% [markdown]
# ### 7. Give an example of how this model could be used for prediction and how this model could be used for inference.
#
# **Be sure to make it clear which example is associated with prediction and which is associated with inference.**

# %%
# A:

# %% [markdown]
# ### 8: [Bonus] Using the model you came up with in Problem 5, calculate and plot the residuals.

# %%
# Using a for loop to loop through the square feet values to calculate the y predictions
# and saving them in a list

y_pred = []

for x in shd['sq__ft']:
    # y = mx + b
    y = 125.31*x + 29984.36
    y_pred.append(y)

# %%
# Lets add these predictions to the DataFrame and calculate the residuals

shd['predictions'] = y_pred
shd['residuals'] = abs(shd.price - shd.predictions)

shd['residuals'].mean()
# Out:
# 60221.8004551046

# %%
sns.lmplot(x='price', y='predictions', data=shd)

# %%
]
